# %%
def f(x):
    return x**2 - 2

def deriv(f,x,h=1e-7):
    return (f(x+h)-f(x))/h

def newtonRaphson(f,x,tol=1e-6,max_iter=1000):
    for i in range(max_iter):
        fx=f(x)
        fpx=deriv(f,x)
        if abs(fpx)<1e-12:
            return None
        x_new = x - fx/fpx
        error = abs(x_new-x)
        print(f"iterations {i}, x = {x_new}")
        if error < tol:
            print(f"final is {x_new}")
            return None
        x=x_new

newtonRaphson(f,1.0)
# Out:
# iterations 0, x = 1.4999999747280497
# iterations 1, x = 1.41666666813394
# iterations 2, x = 1.4142156863658983
# iterations 3, x = 1.4142135623747674
# iterations 4, x = 1.4142135623730951
# final is 1.4142135623730951

# %%
def f(x):
    return x**2 - 2

def deriv(f,x,h=1e-7):
    return (f(x+h)-f(x))/h

def newtonRaphson(f,x,tol=1e-6,max_iter=1000):
    for i in range(max_iter):
        fx=f(x)
        fpx=deriv(f,x)
        x_new=x-fx/fpx
        print(f"iter{i}: x = {x_new}")
        error = abs(x_new-x)
        if error<tol:
            print(f"final answer reached after {i} iteration, x = {x_new}")
            return None
        x= x_new
        
newtonRaphson(f,1.0)
# Out:
# iter0: x = 0.5000000252719503
# iter1: x = 0.2500000374772135
# iter2: x = 0.12500004375331553
# iter3: x = 0.06250004687401556
# iter4: x = 0.031250048438694875
# iter5: x = 0.01562504921993533
# iter6: x = 0.007812549609847935
# iter7: x = 0.0039062998047442385
# iter8: x = 0.001953174902055455
# iter9: x = 0.0009766124503863814
# iter10: x = 0.0004883312239136409
# iter11: x = 0.0002441906093971981
# iter12: x = 0.00012212029958070982
# iter13: x = 6.108513955873789e-05
# iter14: x = 3.056754933286417e-05
# iter15: x = 1.53087338401734e-05
# iter16: x = 7.679285533169378e-06
# iter17: x = 3.864481044004451e-06
# iter18: x = 1.9569211948715133e-06
# iter19: x = 1.0028377528501313e-06
# final answer reached after 19 iteration, x = 1.0028377528501313e-06
